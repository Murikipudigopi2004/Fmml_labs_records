# %% [markdown]
# <a href="https://colab.research.google.com/github/Murikipudigopi2004/Fmml_labs_records/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-09 16:45:20--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  93.1MB/s    in 0.7s
#
# 2024-05-09 16:45:23 (93.1 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6722   1705.08481v2  We study pool-based active learning with abste...  stat
# 5160    1011.3090v2  Multiple kernel learning (MKL), structured spa...  stat
# 12683   1402.1947v1  Health informatics deal with the methods used ...    cs
# 11469  1602.07194v2  In recent years it has become popular to study...  stat
# 17777  1802.09884v1  Live blogs are an increasingly popular news fo...    cs
# ...             ...                                                ...   ...
# 11046   1312.1613v1  Nonnegative Matrix Factorization (NMF) has bee...  stat
# 21638   1209.1996v1  We offer a novel view of AdaBoost in a statist...  stat
# 22096   1411.1670v1  Variational inference algorithms have proven s...  stat
# 8265    1412.6018v1  The paper presents a novel technique called "S...    cs
# 4459   1712.06229v1  This work presents a novel approach for robust...  stat
#
#                                                    title  year  \
# 6722   Bayesian Pool-based Active Learning With Abste...  2017
# 5160   Regularization Strategies and Empirical Bayesi...  2010
# 12683  Classification Tree Diagrams in Health Informa...  2014
# 11469  Lens depth function and k-relative neighborhoo...  2016
# 17777                 Live Blog Corpus for Summarization  2018
# ...                                                  ...   ...
# 11046  Max-Min Distance Nonnegative Matrix Factorization  2013
# 21638                          A Bayesian Boosting Model  2012
# 22096  Stochastic Variational Inference for Hidden Ma...  2014
# 8265   Automatic Training Data Synthesis for Handwrit...  2014
# 4459   Panoramic Robust PCA for Foreground-Background...  2017
#
#                                                 keywords
# 6722   [abstention, feedbacks, abstention, important,...
# 5160   [structured, considerable, attention, differen...
# 12683  [informatics, acquisition, retrieval, informat...
# 11469  [information, numerical, measurements, informa...
# 17777  [increasingly, journalism, summaries, availabl...
# ...                                                  ...
# 11046  [nonnegative, factorization, representation, c...
# 21638  [statistical, classification, hierarchically, ...
# 22096  [variational, inference, algorithms, successfu...
# 8265   [technique, structural, synthesize, qualified,...
# 4459   [variation, regularization, foreground, backgr...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6722     [abstention, feedbacks, abstention, important,...
# 5160     [structured, considerable, attention, differen...
# 12683    [informatics, acquisition, retrieval, informat...
# 11469    [information, numerical, measurements, informa...
# 17777    [increasingly, journalism, summaries, availabl...
#                                ...
# 14571    [glottochronologic, retrognostic, glottochrono...
# 23418    [different, parameters, magnification, magnifi...
# 14986    [introduce, disfluency, detection, bidirection...
# 6135     [framework, aggregated, wasserstein, computing...
# 31455    [generative, adversarial, applications, proces...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8827 words.
# Out of those 4598 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f0402242-0505-404b-ac2a-6764102d5f26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0402242-0505-404b-ac2a-6764102d5f26")) {                    Plotly.newPlot(                        "f0402242-0505-404b-ac2a-6764102d5f26",                        [{"x":["applications","optimality","important","feedbacks","incorporating","estimated","guarantees","scenarios","experiments","practical","respectively","approximation","classification","algorithms","abstention","maximization","considerable","preferable","structured","conjugate","systematically","generative","usefulness","regularizer","numerical","empirical","naturally","components","likelihood","simplicity","regularization","represented","comparable","attention","particular","operation","information","strategies","separable","probabilistic","combination","understood","different","interested","surveillance","knowledge","acquisition","detection","approaches","application","parametric","representation","retrieval","healthcare","particularly","interactive","informatics","visualization","estimation","identification","drawbacks","estimating","clustering","parallelized","versatile","neighborhood","measurements","euclidean","embedding","construct","statistics","explicitly","comparisons","encourage","reconstruct","replicate","challenges","summarization","collecting","community","summaries","available","increasingly","evaluation","automatic","generation","constructing","constructed","corresponding","challenge","recurrent","difficult","promising","introduce","partially","relevance","theoretic","predictive","motivation","entropies","computation","relations","computational","empirically","expensive","maintains","performance","successful","tremendously","establish","criterion","computing","optimization","dimensional","compelling","efficient","techniques","simulations","demonstrated","complexity","demonstrates","evaluations","localized","alternative","meaningful","introducing","subgradient","calculated","benchmark","traditional","expressed","implications","continuity","individual","curvature","functions","stochastic","statistical","precision","alignment","extraction","predicting","redundant","framework","separated","calculation","trainable","simultaneously","landmarks","convolutional","independent","similarity","geometric","identities","transformation","verification","analyzing","supervised","recognition","violations","constraints","variables","implement","technique","describes","constraint","competitive","personnel","automaton","incrementally","practicality","submodular","characterization","tractable","including","polynomial","inference","decomposition","configuration","extensions","efficiently","densities","multivariate","occurring","canonical","advantage","dependency","continuous","synthetic","flexibility","correlation","demonstrate","increased","arbitrary","providing","significantly","interpretability","formulate","conditioned","intricate"],"y":[422,26,318,4,53,66,85,94,603,111,88,120,528,605,0,31,31,2,103,5,21,118,29,20,76,157,66,88,57,23,85,91,103,176,250,35,729,114,17,146,135,22,783,24,19,346,44,319,452,247,46,340,98,8,74,44,3,26,219,117,15,62,154,12,9,21,49,39,104,93,56,64,28,13,28,5,104,29,18,84,15,326,54,259,196,135,45,60,132,141,145,147,115,345,48,42,37,69,14,2,151,81,276,76,62,7,846,72,2,55,38,142,321,175,8,415,354,42,106,238,46,49,14,91,61,41,2,27,216,179,29,26,6,105,8,227,119,150,84,47,139,87,22,539,15,13,30,139,16,385,134,150,71,10,58,40,57,222,372,5,149,131,70,232,83,86,113,5,4,13,2,15,32,30,236,55,193,61,22,37,138,7,31,13,25,89,44,113,130,28,70,527,44,85,85,275,12,53,21,3],"type":"bar"},{"x":["applications","optimality","important","feedbacks","incorporating","estimated", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4598,), (4598, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.82

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Comparative</span> <span style=''>Analysis</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Applicability</span> <span style=''>of</span> <span style=''>Entropy</span> <span style=''>in</span> <span style=''>remote</span> <span style=''>sensing</span> <br/><br/><span style=''>Entropy</span> <span style=''>is</span> <span style=''>the</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style=''>any</span> <span style=''>data</span> <span style=''>and</span> <span style=''>is</span> <span style=''>adopted</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximisation</span> <span style=''>of</span> <span style=''>mutual</span> <span style='background-color:rgba(0, 255, 0, 0.3376146788990826);'>information</span> <span style=''>in</span> <span style=''>many</span> <span style=''>remote</span> <span style=''>sensing</span> <span style='background-color:rgba(0, 255, 0, 0.5051546391752577);'>operations</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.4814814814814815);'>availability</span> <span style=''>of</span> <span style=''>wide</span> <span style=''>entropy</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>variations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivated</span> <span style=''>us</span> <span style=''>for</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3617021276595743);'>investigation</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>suitability</span> <span style='background-color:rgba(0, 255, 0, 0.42857142857142855);'>preference</span> <span style=''>of</span> <span style=''>these</span> <span style=''>versions</span> <span style=''>to</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.5051546391752577);'>operations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Methodologies</span> <span style=''>were</span> <span style='background-color:rgba(0, 255, 0, 0.34146341463414637);'>implemented</span> <span style=''>in</span> <span style=''>Matlab</span> <span style=''>and</span> <span style=''>were</span> <span style=''>enhanced</span> <span style=''>with</span> <span style=''>entropy</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>variations</span> <span style='background-color:rgba(0, 255, 0, 0.4509803921568627);'>Evaluation</span> <span style=''>of</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementations</span> <span style=''>was</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3361774744027303);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.35897435897435903);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.5499999999999998);'>reference</span> <span style=''>to</span> <span style=''>the</span> <span style=''>study</span> <span style=''>area</span> <span style=''>The</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>versions</span> <span style=''>like</span> <span style=''>Tsallis</span> <span style=''>Shanons</span> <span style=''>and</span> <span style=''>Renyis</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>entropies</span> <span style=''>were</span> <span style=''>analysed</span> <span style=''>in</span> <span style=''>context</span> <span style=''>of</span> <span style=''>various</span> <span style=''>remote</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Understanding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style=''>Sparse</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximations</span> <br/><br/><span style=''>Good</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essential</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>exact</span> <span style=''>methods</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prohibitive</span> <span style=''>for</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>The</span> <span style=''>Fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Independent</span> <span style=''>Training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style=''>(FITC)</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Free</span> <span style=''>Energy</span> <span style=''>(VFE)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>are</span> <span style=''>two</span> <span style=''>recent</span> <span style=''>popular</span> <span style=''>methods</span> <span style=''>Despite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>superficial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarities</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surprisingly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>and</span> <span style=''>behave</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differently</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thoroughly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>two</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytically</span> <span style=''>and</span> <span style=''>through</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrative</span> <span style=''>examples</span> <span style=''>and</span> <span style=''>draw</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conclusions</span> <span style=''>to</span> <span style=''>guide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Geodesic</span> <span style=''>Distance</span> <span style=''>between</span> <span style=''>mathcalG</span> <span style=''>I0</span> <span style=''>Models</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Application</span> <span style=''>to</span> <span style=''>Region</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discrimination</span> <br/><br/><span style=''>The</span> <span style=''>mathcalG</span> <span style=''>I0</span> <span style='background-color:rgba(255, 0, 0, 0.31468531468531474);'>distribution</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style='background-color:rgba(0, 255, 0, 0.3361774744027303);'>different</span> <span style=''>regions</span> <span style=''>in</span> <span style=''>monopolarized</span> <span style=''>SAR</span> <span style=''>imagery</span> <span style=''>It</span> <span style=''>is</span> <span style=''>indexed</span> <span style=''>by</span> <span style=''>three</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>looks</span> <span style=''>(which</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimated</span> <span style=''>in</span> <span style=''>the</span> <span style=''>whole</span> <span style=''>image)</span> <span style=''>a</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>and</span> <span style=''>a</span> <span style=''>texture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>new</span> <span style=''>proposal</span> <span style=''>for</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.5795454545454546);'>extraction</span> <span style=''>and</span> <span style=''>region</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrimination</span> <span style=''>in</span> <span style=''>SAR</span> <span style=''>imagery</span> <span style=''>using</span> <span style=''>the</span> <span style=''>geodesic</span> <span style=''>distance</span> <span style=''>as</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>between</span> <span style=''>mathcalG</span> <span style=''>I0</span> <span style=''>models</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>geodesic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distances</span> <span style=''>between</span> <span style=''>models</span> <span style=''>that</span> <span style=''>describe</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situations</span> <span style=''>assuming</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>looks</span> <span style=''>known</span> <span style=''>for</span> <span style=''>same</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3361774744027303);'>different</span> <span style=''>texture</span> <span style=''>and</span> <span style=''>for</span> <span style=''>same</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3361774744027303);'>different</span> <span style=''>scale</span> <span style=''>We</span> <span style=''>then</span> <span style=''>apply</span> <span style=''>this</span> <span style=''>new</span> <span style=''>tool</span> <span style=''>to</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Gaussian</span> <span style=''>Mixture</span> <span style=''>Modeling</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>Latent</span> <span style=''>Variable</span> <span style=''>Models</span> <br/><br/><span style=''>Density</span> <span style=''>modeling</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>notoriously</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>One</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>to</span> <span style=''>search</span> <span style=''>for</span> <span style=''>a</span> <span style=''>lower</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>manifold</span> <span style=''>which</span> <span style=''>captures</span> <span style=''>the</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristics</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>Recently</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>Latent</span> <span style=''>Variable</span> <span style=''>Model</span> <span style=''>(GPLVM)</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successfully</span> <span style=''>been</span> <span style=''>used</span> <span style=''>to</span> <span style=''>find</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>in</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>complex</span> <span style=''>data</span> <span style=''>The</span> <span style=''>GPLVM</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>points</span> <span style=''>in</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>latent</span> <span style=''>space</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>map</span> <span style=''>to</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>space</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpreted</span> <span style=''>as</span> <span style=''>a</span> <span style=''>density</span> <span style=''>model</span> <span style=''>in</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>space</span> <span style=''>However</span> <span style=''>the</span> <span style=''>GPLVM</span> <span style=''>is</span> <span style=''>not</span> <span style=''>trained</span> <span style=''>as</span> <span style=''>a</span> <span style=''>density</span> <span style=''>model</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>therefore</span> <span style=''>yields</span> <span style=''>bad</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>training</span> <span style=''>strategy</span> <span style=''>and</span> <span style=''>obtain</span> <span style=''>improved</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10125223613595706)
# 	processing (0.10518783542039356)
# 	segmentation (0.06833631484794275)
# 	architecture (0.09445438282647585)
# 	experimental (0.14311270125223613)
# 	detection (0.11413237924865832)
# 	information (0.2608228980322004)
# 	different (0.28014311270125225)
# 	recognition (0.1330948121645796)
# 	convolutional (0.13774597495527727)
#
# Some Statistics words are:
# 	variables (0.13316708229426433)
# 	theoretical (0.142643391521197)
# 	stochastic (0.1376558603491272)
# 	estimation (0.1800498753117207)
# 	statistical (0.15860349127182044)
# 	algorithm (0.3945137157107232)
# 	distribution (0.18753117206982545)
# 	dimensional (0.1885286783042394)
# 	inference (0.19950124688279303)
# 	regression (0.17805486284289276)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a506f87a-4715-4df3-968c-8104cc24e4b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a506f87a-4715-4df3-968c-8104cc24e4b9")) {                    Plotly.newPlot(                        "a506f87a-4715-4df3-968c-8104cc24e4b9",                        [{"x":["applications","optimality","important","feedbacks","incorporating","estimated","guarantees","scenarios","experiments","practical","respectively","approximation","classification","algorithms","abstention","maximization","considerable","preferable","structured","conjugate","systematically","generative","usefulness","regularizer","numerical","empirical","naturally","components","likelihood","simplicity","regularization","represented","comparable","attention","particular","operation","information","strategies","separable","probabilistic","combination","understood","different","interested","surveillance","knowledge","acquisition","detection","approaches","application","parametric","representation","retrieval","healthcare","particularly","interactive","informatics","visualization","estimation","identification","drawbacks","estimating","clustering","parallelized","versatile","neighborhood","measurements","euclidean","embedding","construct","statistics","explicitly","comparisons","encourage","reconstruct","replicate","challenges","summarization","collecting","community","summaries","available","increasingly","evaluation","automatic","generation","constructing","constructed","corresponding","challenge","recurrent","difficult","promising","introduce","partially","relevance","theoretic","predictive","motivation","entropies","computation","relations","computational","empirically","expensive","maintains","performance","successful","tremendously","establish","criterion","computing","optimization","dimensional","compelling","efficient","techniques","simulations","demonstrated","complexity","demonstrates","evaluations","localized","alternative","meaningful","introducing","subgradient","calculated","benchmark","traditional","expressed","implications","continuity","individual","curvature","functions","stochastic","statistical","precision","alignment","extraction","predicting","redundant","framework","separated","calculation","trainable","simultaneously","landmarks","convolutional","independent","similarity","geometric","identities","transformation","verification","analyzing","supervised","recognition","violations","constraints","variables","implement","technique","describes","constraint","competitive","personnel","automaton","incrementally","practicality","submodular","characterization","tractable","including","polynomial","inference","decomposition","configuration","extensions","efficiently","densities","multivariate","occurring","canonical","advantage","dependency","continuous","synthetic","flexibility","correlation","demonstrate","increased","arbitrary","providing","significantly","interpretability","formulate","conditioned","intricate","substantially","exceptionally","plausible","prediction","challenging","implementation","observations","predictions","simplifying","assumptions","dimensionality","understanding","capability","variational","assumption","deterministic","unpredictable","effective","environment","stochasticity","publication","variation","relatively","conventional","outperforms","complement","importance","selecting","regression","interpreting","classifier","influence","principles","coalitional","coefficients","innovations","presented","structural","reconstructed","interactions","functional","principle","consisting","associating","processes","multiview","progressively","structure","proposals","refinement","achieving","occlusion","organized","interaction","synchronized","c ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	abstention
# 	factoring
# 	trilinear
# 	biomarker
# 	prognostic
# 	misspecification
# 	nonparanormal
# 	invertibility
# 	reparameterized
# 	differentiability
# 	traintest
# 	distinguishability
# 	chemometrics
# 	embarrassingly
# 	wirtinger
# 	parametrisation
# 	recasting
# 	counterfactual
# 	multiplayer
# 	scrambled
# Some words which never appear in Statistics papers:
# 	personnel
# 	automaton
# 	exceptionally
# 	unpredictable
# 	upscaling
# 	musculoskeletal
# 	syntactic
# 	historians
# 	intellectual
# 	scholarly
# 	humanities
# 	activeness
# 	publishing
# 	resembling
# 	precondition
# 	submissions
# 	annotating
# 	arranging
# 	stagnation
# 	benefited

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.072385400024579e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7841666666666667
